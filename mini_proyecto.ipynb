# %% [markdown]
# ## Patched Conics - Artemis

# %%
pip install -Uq pymcel
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python (.venv WSL Documentos)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pymcel as pc
import numpy as np
import matplotlib.pyplot as plt
import pymcel as pc
import spiceypy
import astropy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pymcel as pc
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pymcel'
